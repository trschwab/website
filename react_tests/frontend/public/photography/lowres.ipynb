# %%
import os
from PIL import Image, ExifTags

def correct_image_orientation(img):
    try:
        for orientation in ExifTags.TAGS.keys():
            if ExifTags.TAGS[orientation] == 'Orientation':
                break
        exif = img._getexif()
        if exif is not None:
            orientation = exif.get(orientation, None)
            if orientation == 3:
                img = img.rotate(180, expand=True)
            elif orientation == 6:
                img = img.rotate(270, expand=True)
            elif orientation == 8:
                img = img.rotate(90, expand=True)
    except (AttributeError, KeyError, IndexError):
        # Cases where there is no EXIF data or orientation information
        pass
    return img

def create_low_res_image(input_path, output_path, scale_factor):
    with Image.open(input_path) as img:
        # Correct orientation based on EXIF data
        img = correct_image_orientation(img)
        
        # Calculate new dimensions
        new_width = int(img.width * scale_factor)
        new_height = int(img.height * scale_factor)
        
        # Resize the image
        img = img.resize((new_width, new_height), Image.ANTIALIAS)
        
        # Save the resized image
        img.save(output_path)

def process_directory(input_dir, output_dir, scale_factor):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(('png', 'jpg', 'jpeg', 'tiff', 'bmp', 'gif')):
                input_path = os.path.join(root, file)
                print(f"Attempting {input_path}")
                relative_path = os.path.relpath(input_path, input_dir)
                output_path = os.path.join(output_dir, relative_path)

                output_dir_for_file = os.path.dirname(output_path)
                if not os.path.exists(output_dir_for_file):
                    os.makedirs(output_dir_for_file)

                create_low_res_image(input_path, output_path, scale_factor)
                print(f'Converted {input_path} to {output_path}')

input_directory = "./toadd/"
output_directory = "./midres/"
scale_factor = 0.8

process_directory(input_directory, output_directory, scale_factor)

input_directory = "./toadd/"
output_directory = "./lowres/"
scale_factor = 0.5

process_directory(input_directory, output_directory, scale_factor)
# Out:
# Attempting ./toadd/06660023.JPG
# Converted ./toadd/06660023.JPG to ./midres/06660023.JPG
# Attempting ./toadd/06580033.JPG
# Converted ./toadd/06580033.JPG to ./midres/06580033.JPG
# Attempting ./toadd/06630012.JPG
# Converted ./toadd/06630012.JPG to ./midres/06630012.JPG
# Attempting ./toadd/06620016.JPG
# Converted ./toadd/06620016.JPG to ./midres/06620016.JPG
# Attempting ./toadd/06580032.JPG
# Converted ./toadd/06580032.JPG to ./midres/06580032.JPG
# Attempting ./toadd/06770019.JPG
# Converted ./toadd/06770019.JPG to ./midres/06770019.JPG
# Attempting ./toadd/06770031.JPG
# Converted ./toadd/06770031.JPG to ./midres/06770031.JPG
# Attempting ./toadd/06660020.JPG
# Converted ./toadd/06660020.JPG to ./midres/06660020.JPG
# Attempting ./toadd/06540016.JPG
# Converted ./toadd/06540016.JPG to ./midres/06540016.JPG
# Attempting ./toadd/06620014.JPG
# Converted ./toadd/06620014.JPG to ./midres/06620014.JPG
# Attempting ./toadd/06620015.JPG
# Converted ./toadd/06620015.JPG to ./midres/06620015.JPG
# Attempting ./toadd/06620001.JPG
# Converted ./toadd/06620001.JPG to ./midres/06620001.JPG
# Attempting ./toadd/06730010.JPG
# Converted ./toadd/06730010.JPG to ./midres/06730010.JPG
# Attempting ./toadd/06730004.JPG
# Converted ./toadd/06730004.JPG to ./midres/06730004.JPG
# Attempting ./toadd/06660009.JPG
# Converted ./toadd/06660009.JPG to ./midres/06660009.JPG
# Attempting ./toadd/06770030.JPG
# Converted ./toadd/06770030.JPG to ./midres/06770030.JPG
# Attempting ./toadd/06660031.JPG
# Converted ./toadd/06660031.JPG to ./midres/06660031.JPG
# Attempting ./toadd/06760031.JPG
# Converted ./toadd/06760031.JPG to ./midres/06760031.JPG
# Attempting ./toadd/06660019.JPG
# Converted ./toadd/06660019.JPG to ./midres/06660019.JPG
# Attempting ./toadd/06580009.JPG
# Converted ./toadd/06580009.JPG to ./midres/06580009.JPG
# Attempting ./toadd/06730014.JPG
# Converted ./toadd/06730014.JPG to ./midres/06730014.JPG
# Attempting ./toadd/06550002.JPG
# Converted ./toadd/06550002.JPG to ./midres/06550002.JPG
# Attempting ./toadd/06550016.JPG
# Converted ./toadd/06550016.JPG to ./midres/06550016.JPG
# Attempting ./toadd/06620005.JPG
# Converted ./toadd/06620005.JPG to ./midres/06620005.JPG
# Attempting ./toadd/06540013.JPG
# Converted ./toadd/06540013.JPG to ./midres/06540013.JPG
# Attempting ./toadd/06590019.JPG
# Converted ./toadd/06590019.JPG to ./midres/06590019.JPG
# Attempting ./toadd/06720010.JPG
# Converted ./toadd/06720010.JPG to ./midres/06720010.JPG
# Attempting ./toadd/06730029.JPG
# Converted ./toadd/06730029.JPG to ./midres/06730029.JPG
# Attempting ./toadd/06730001.JPG
# Converted ./toadd/06730001.JPG to ./midres/06730001.JPG
# Attempting ./toadd/06770035.JPG
# Converted ./toadd/06770035.JPG to ./midres/06770035.JPG
# Attempting ./toadd/06670037.JPG
# Converted ./toadd/06670037.JPG to ./midres/06670037.JPG
# Attempting ./toadd/06720006.JPG
# Converted ./toadd/06720006.JPG to ./midres/06720006.JPG
# Attempting ./toadd/06540004.JPG
# Converted ./toadd/06540004.JPG to ./midres/06540004.JPG
# Attempting ./toadd/06630016.JPG
# Converted ./toadd/06630016.JPG to ./midres/06630016.JPG
# Attempting ./toadd/06710028.JPG
# Converted ./toadd/06710028.JPG to ./midres/06710028.JPG
# Attempting ./toadd/06570002.JPG
# Converted ./toadd/06570002.JPG to ./midres/06570002.JPG
# Attempting ./toadd/06600011.JPG
# Converted ./toadd/06600011.JPG to ./midres/06600011.JPG
# Attempting ./toadd/06700011.JPG
# Converted ./toadd/06700011.JPG to ./midres/06700011.JPG
# Attempting ./toadd/06750008.JPG
# Converted ./toadd/06750008.JPG to ./midres/06750008.JPG
# Attempting ./toadd/06530036.JPG
# Converted ./toadd/06530036.JPG to ./midres/06530036.JPG
# Attempting ./toadd/06520033.JPG
# Converted ./toadd/06520033.JPG to ./midres/06520033.JPG
# Attempting ./toadd/06740031.JPG
# Converted ./toadd/06740031.JPG to ./midres/06740031.JPG
# Attempting ./toadd/06740024.JPG
# Converted ./toadd/06740024.JPG to ./midres/06740024.JPG
# Attempting ./toadd/06520032.JPG
# Converted ./toadd/06520032.JPG to ./midres/06520032.JPG
# Attempting ./toadd/06650035.JPG
# Converted ./toadd/06650035.JPG to ./midres/06650035.JPG
# Attempting ./toadd/06680002.JPG
# Converted ./toadd/06680002.JPG to ./midres/06680002.JPG
# Attempting ./toadd/06530037.JPG
# Converted ./toadd/06530037.JPG to ./midres/06530037.JPG
# Attempting ./toadd/06610015.JPG
# Converted ./toadd/06610015.JPG to ./midres/06610015.JPG
# Attempting ./toadd/06610029.JPG
# Converted ./toadd/06610029.JPG to ./midres/06610029.JPG
# Attempting ./toadd/06710029.JPG
# Converted ./toadd/06710029.JPG to ./midres/06710029.JPG
# Attempting ./toadd/06710003.JPG
# Converted ./toadd/06710003.JPG to ./midres/06710003.JPG
# Attempting ./toadd/06570029.JPG
# Converted ./toadd/06570029.JPG to ./midres/06570029.JPG
# Attempting ./toadd/06560004.JPG
# Converted ./toadd/06560004.JPG to ./midres/06560004.JPG
# Attempting ./toadd/06680028.JPG
# Converted ./toadd/06680028.JPG to ./midres/06680028.JPG
# Attempting ./toadd/06530009.JPG
# Converted ./toadd/06530009.JPG to ./midres/06530009.JPG
# Attempting ./toadd/06640027.JPG
# Converted ./toadd/06640027.JPG to ./midres/06640027.JPG
# Attempting ./toadd/06680001.JPG
# Converted ./toadd/06680001.JPG to ./midres/06680001.JPG
# Attempting ./toadd/06530034.JPG
# Converted ./toadd/06530034.JPG to ./midres/06530034.JPG
# Attempting ./toadd/06700013.JPG
# Converted ./toadd/06700013.JPG to ./midres/06700013.JPG
# Attempting ./toadd/06710002.JPG
# Converted ./toadd/06710002.JPG to ./midres/06710002.JPG
# Attempting ./toadd/06570010.JPG
# Converted ./toadd/06570010.JPG to ./midres/06570010.JPG
# Attempting ./toadd/06700003.JPG
# Converted ./toadd/06700003.JPG to ./midres/06700003.JPG
# Attempting ./toadd/06680011.JPG
# Converted ./toadd/06680011.JPG to ./midres/06680011.JPG
# Attempting ./toadd/06740023.JPG
# Converted ./toadd/06740023.JPG to ./midres/06740023.JPG
# Attempting ./toadd/06520021.JPG
# Converted ./toadd/06520021.JPG to ./midres/06520021.JPG
# Attempting ./toadd/06520020.JPG
# Converted ./toadd/06520020.JPG to ./midres/06520020.JPG
# Attempting ./toadd/06520008.JPG
# Converted ./toadd/06520008.JPG to ./midres/06520008.JPG
# Attempting ./toadd/06640036.JPG
# Converted ./toadd/06640036.JPG to ./midres/06640036.JPG
# Attempting ./toadd/06740022.JPG
# Converted ./toadd/06740022.JPG to ./midres/06740022.JPG
# Attempting ./toadd/06650033.JPG
# Converted ./toadd/06650033.JPG to ./midres/06650033.JPG
# Attempting ./toadd/06750027.JPG
# Converted ./toadd/06750027.JPG to ./midres/06750027.JPG
# Attempting ./toadd/06700002.JPG
# Converted ./toadd/06700002.JPG to ./midres/06700002.JPG
# Attempting ./toadd/06570011.JPG
# Converted ./toadd/06570011.JPG to ./midres/06570011.JPG
# Attempting ./toadd/06570005.JPG
# Converted ./toadd/06570005.JPG to ./midres/06570005.JPG
# Attempting ./toadd/06680006.JPG
# Converted ./toadd/06680006.JPG to ./midres/06680006.JPG
# Attempting ./toadd/06650025.JPG
# Converted ./toadd/06650025.JPG to ./midres/06650025.JPG
# Attempting ./toadd/06530033.JPG
# Converted ./toadd/06530033.JPG to ./midres/06530033.JPG
# Attempting ./toadd/06650019.JPG
# Converted ./toadd/06650019.JPG to ./midres/06650019.JPG
# Attempting ./toadd/06690017.JPG
# Converted ./toadd/06690017.JPG to ./midres/06690017.JPG
# Attempting ./toadd/06690003.JPG
# Converted ./toadd/06690003.JPG to ./midres/06690003.JPG
# Attempting ./toadd/06690002.JPG
# Converted ./toadd/06690002.JPG to ./midres/06690002.JPG
# Attempting ./toadd/06690016.JPG
# Converted ./toadd/06690016.JPG to ./midres/06690016.JPG
# Attempting ./toadd/06680007.JPG
# Converted ./toadd/06680007.JPG to ./midres/06680007.JPG
# Attempting ./toadd/06650030.JPG
# Converted ./toadd/06650030.JPG to ./midres/06650030.JPG
# Attempting ./toadd/06610010.JPG
# Converted ./toadd/06610010.JPG to ./midres/06610010.JPG
# Attempting ./toadd/06570023.JPG
# Converted ./toadd/06570023.JPG to ./midres/06570023.JPG
# Attempting ./toadd/06710035.JPG
# Converted ./toadd/06710035.JPG to ./midres/06710035.JPG
# Attempting ./toadd/06700018.JPG
# Converted ./toadd/06700018.JPG to ./midres/06700018.JPG
# Attempting ./toadd/06650029.JPG
# Converted ./toadd/06650029.JPG to ./midres/06650029.JPG
# Attempting ./toadd/06530017.JPG
# Converted ./toadd/06530017.JPG to ./midres/06530017.JPG
# Attempting ./toadd/06690033.JPG
# Converted ./toadd/06690033.JPG to ./midres/06690033.JPG
# Attempting ./toadd/06600025.JPG
# Converted ./toadd/06600025.JPG to ./midres/06600025.JPG
# Attempting ./toadd/06700019.JPG
# Converted ./toadd/06700019.JPG to ./midres/06700019.JPG
# Attempting ./toadd/06560027.JPG
# Converted ./toadd/06560027.JPG to ./midres/06560027.JPG
# Attempting ./toadd/06570022.JPG
# Converted ./toadd/06570022.JPG to ./midres/06570022.JPG
# Attempting ./toadd/06570036.JPG
# Converted ./toadd/06570036.JPG to ./midres/06570036.JPG
# Attempting ./toadd/06710022.JPG
# Converted ./toadd/06710022.JPG to ./midres/06710022.JPG
# Attempting ./toadd/06690019.JPG
# Converted ./toadd/06690019.JPG to ./midres/06690019.JPG
# Attempting ./toadd/06680034.JPG
# Converted ./toadd/06680034.JPG to ./midres/06680034.JPG
# Attempting ./toadd/06530015.JPG
# Converted ./toadd/06530015.JPG to ./midres/06530015.JPG
# Attempting ./toadd/06710033.JPG
# Converted ./toadd/06710033.JPG to ./midres/06710033.JPG
# Attempting ./toadd/06560034.JPG
# Converted ./toadd/06560034.JPG to ./midres/06560034.JPG
# Attempting ./toadd/06530011.JPG
# Converted ./toadd/06530011.JPG to ./midres/06530011.JPG
# Attempting ./toadd/06530005.JPG
# Converted ./toadd/06530005.JPG to ./midres/06530005.JPG
# Attempting ./toadd/06680018.JPG
# Converted ./toadd/06680018.JPG to ./midres/06680018.JPG
# Attempting ./toadd/06690021.JPG
# Converted ./toadd/06690021.JPG to ./midres/06690021.JPG
# Attempting ./toadd/06740017.JPG
# Converted ./toadd/06740017.JPG to ./midres/06740017.JPG
# Attempting ./toadd/06520029.JPG
# Converted ./toadd/06520029.JPG to ./midres/06520029.JPG
# Attempting ./toadd/06740003.JPG
# Converted ./toadd/06740003.JPG to ./midres/06740003.JPG
# Attempting ./toadd/06700009.JPG
# Converted ./toadd/06700009.JPG to ./midres/06700009.JPG
# Attempting ./toadd/06750004.JPG
# Converted ./toadd/06750004.JPG to ./midres/06750004.JPG
# Attempting ./toadd/06680033.JPG
# Converted ./toadd/06680033.JPG to ./midres/06680033.JPG
# Attempting ./toadd/06530012.JPG
# Converted ./toadd/06530012.JPG to ./midres/06530012.JPG
# Attempting ./toadd/06690022.JPG
# Converted ./toadd/06690022.JPG to ./midres/06690022.JPG
# Attempting ./toadd/06530007.JPG
# Converted ./toadd/06530007.JPG to ./midres/06530007.JPG
# Attempting ./toadd/06650005.JPG
# Converted ./toadd/06650005.JPG to ./midres/06650005.JPG
# Attempting ./toadd/06660016.JPG
# Converted ./toadd/06660016.JPG to ./midres/06660016.JPG
# Attempting ./toadd/06760002.JPG
# Converted ./toadd/06760002.JPG to ./midres/06760002.JPG
# Attempting ./toadd/06550019.JPG
# Converted ./toadd/06550019.JPG to ./midres/06550019.JPG
# Attempting ./toadd/06590017.JPG
# Converted ./toadd/06590017.JPG to ./midres/06590017.JPG
# Attempting ./toadd/06540034.JPG
# Converted ./toadd/06540034.JPG to ./midres/06540034.JPG
# Attempting ./toadd/06590003.JPG
# Converted ./toadd/06590003.JPG to ./midres/06590003.JPG
# Attempting ./toadd/06620023.JPG
# Converted ./toadd/06620023.JPG to ./midres/06620023.JPG
# Attempting ./toadd/06540009.JPG
# Converted ./toadd/06540009.JPG to ./midres/06540009.JPG
# Attempting ./toadd/06590016.JPG
# Converted ./toadd/06590016.JPG to ./midres/06590016.JPG
# Attempting ./toadd/06550018.JPG
# Converted ./toadd/06550018.JPG to ./midres/06550018.JPG
# Attempting ./toadd/06630032.JPG
# Converted ./toadd/06630032.JPG to ./midres/06630032.JPG
# Attempting ./toadd/06660017.JPG
# Converted ./toadd/06660017.JPG to ./midres/06660017.JPG
# Attempting ./toadd/06670010.JPG
# Converted ./toadd/06670010.JPG to ./midres/06670010.JPG
# Attempting ./toadd/06660029.JPG
# Converted ./toadd/06660029.JPG to ./midres/06660029.JPG
# Attempting ./toadd/06760001.JPG
# Converted ./toadd/06760001.JPG to ./midres/06760001.JPG
# Attempting ./toadd/06730018.JPG
# Converted ./toadd/06730018.JPG to ./midres/06730018.JPG
# Attempting ./toadd/06630024.JPG
# Converted ./toadd/06630024.JPG to ./midres/06630024.JPG
# Attempting ./toadd/06620035.JPG
# Converted ./toadd/06620035.JPG to ./midres/06620035.JPG
# Attempting ./toadd/06730031.JPG
# Converted ./toadd/06730031.JPG to ./midres/06730031.JPG
# Attempting ./toadd/06630025.JPG
# Converted ./toadd/06630025.JPG to ./midres/06630025.JPG
# Attempting ./toadd/06550033.JPG
# Converted ./toadd/06550033.JPG to ./midres/06550033.JPG
# Attempting ./toadd/06760014.JPG
# Converted ./toadd/06760014.JPG to ./midres/06760014.JPG
# Attempting ./toadd/06660014.JPG
# Converted ./toadd/06660014.JPG to ./midres/06660014.JPG
# Attempting ./toadd/06660010.JPG
# Converted ./toadd/06660010.JPG to ./midres/06660010.JPG
# Attempting ./toadd/06760010.JPG
# Converted ./toadd/06760010.JPG to ./midres/06760010.JPG
# Attempting ./toadd/06730035.JPG
# Converted ./toadd/06730035.JPG to ./midres/06730035.JPG
# Attempting ./toadd/06630009.JPG
# Converted ./toadd/06630009.JPG to ./midres/06630009.JPG
# Attempting ./toadd/06620024.JPG
# Converted ./toadd/06620024.JPG to ./midres/06620024.JPG
# Attempting ./toadd/06590011.JPG
# Converted ./toadd/06590011.JPG to ./midres/06590011.JPG
# Attempting ./toadd/06580001.JPG
# Converted ./toadd/06580001.JPG to ./midres/06580001.JPG
# Attempting ./toadd/06660011.JPG
# Converted ./toadd/06660011.JPG to ./midres/06660011.JPG
# Attempting ./toadd/06760005.JPG
# Converted ./toadd/06760005.JPG to ./midres/06760005.JPG
# Attempting ./toadd/06660013.JPG
# Converted ./toadd/06660013.JPG to ./midres/06660013.JPG
# Attempting ./toadd/06630036.JPG
# Converted ./toadd/06630036.JPG to ./midres/06630036.JPG
# Attempting ./toadd/06730022.JPG
# Converted ./toadd/06730022.JPG to ./midres/06730022.JPG
# Attempting ./toadd/06580017.JPG
# Converted ./toadd/06580017.JPG to ./midres/06580017.JPG
# Attempting ./toadd/06720027.JPG
# Converted ./toadd/06720027.JPG to ./midres/06720027.JPG
# Attempting ./toadd/06550021.JPG
# Converted ./toadd/06550021.JPG to ./midres/06550021.JPG
# Attempting ./toadd/06760006.JPG
# Converted ./toadd/06760006.JPG to ./midres/06760006.JPG
# Attempting ./toadd/06660012.JPG
# Converted ./toadd/06660012.JPG to ./midres/06660012.JPG
# Attempting ./toadd/06670017.JPG
# Converted ./toadd/06670017.JPG to ./midres/06670017.JPG
# Attempting ./toadd/06660023.JPG
# Converted ./toadd/06660023.JPG to ./lowres/06660023.JPG
# Attempting ./toadd/06580033.JPG
# Converted ./toadd/06580033.JPG to ./lowres/06580033.JPG
# Attempting ./toadd/06630012.JPG
# Converted ./toadd/06630012.JPG to ./lowres/06630012.JPG
# Attempting ./toadd/06620016.JPG
# Converted ./toadd/06620016.JPG to ./lowres/06620016.JPG
# Attempting ./toadd/06580032.JPG
# Converted ./toadd/06580032.JPG to ./lowres/06580032.JPG
# Attempting ./toadd/06770019.JPG
# Converted ./toadd/06770019.JPG to ./lowres/06770019.JPG
# Attempting ./toadd/06770031.JPG
# Converted ./toadd/06770031.JPG to ./lowres/06770031.JPG
# Attempting ./toadd/06660020.JPG
# Converted ./toadd/06660020.JPG to ./lowres/06660020.JPG
# Attempting ./toadd/06540016.JPG
# Converted ./toadd/06540016.JPG to ./lowres/06540016.JPG
# Attempting ./toadd/06620014.JPG
# Converted ./toadd/06620014.JPG to ./lowres/06620014.JPG
# Attempting ./toadd/06620015.JPG
# Converted ./toadd/06620015.JPG to ./lowres/06620015.JPG
# Attempting ./toadd/06620001.JPG
# Converted ./toadd/06620001.JPG to ./lowres/06620001.JPG
# Attempting ./toadd/06730010.JPG
# Converted ./toadd/06730010.JPG to ./lowres/06730010.JPG
# Attempting ./toadd/06730004.JPG
# Converted ./toadd/06730004.JPG to ./lowres/06730004.JPG
# Attempting ./toadd/06660009.JPG
# Converted ./toadd/06660009.JPG to ./lowres/06660009.JPG
# Attempting ./toadd/06770030.JPG
# Converted ./toadd/06770030.JPG to ./lowres/06770030.JPG
# Attempting ./toadd/06660031.JPG
# Converted ./toadd/06660031.JPG to ./lowres/06660031.JPG
# Attempting ./toadd/06760031.JPG
# Converted ./toadd/06760031.JPG to ./lowres/06760031.JPG
# Attempting ./toadd/06660019.JPG
# Converted ./toadd/06660019.JPG to ./lowres/06660019.JPG
# Attempting ./toadd/06580009.JPG
# Converted ./toadd/06580009.JPG to ./lowres/06580009.JPG
# Attempting ./toadd/06730014.JPG
# Converted ./toadd/06730014.JPG to ./lowres/06730014.JPG
# Attempting ./toadd/06550002.JPG
# Converted ./toadd/06550002.JPG to ./lowres/06550002.JPG
# Attempting ./toadd/06550016.JPG
# Converted ./toadd/06550016.JPG to ./lowres/06550016.JPG
# Attempting ./toadd/06620005.JPG
# Converted ./toadd/06620005.JPG to ./lowres/06620005.JPG
# Attempting ./toadd/06540013.JPG
# Converted ./toadd/06540013.JPG to ./lowres/06540013.JPG
# Attempting ./toadd/06590019.JPG
# Converted ./toadd/06590019.JPG to ./lowres/06590019.JPG
# Attempting ./toadd/06720010.JPG
# Converted ./toadd/06720010.JPG to ./lowres/06720010.JPG
# Attempting ./toadd/06730029.JPG
# Converted ./toadd/06730029.JPG to ./lowres/06730029.JPG
# Attempting ./toadd/06730001.JPG
# Converted ./toadd/06730001.JPG to ./lowres/06730001.JPG
# Attempting ./toadd/06770035.JPG
# Converted ./toadd/06770035.JPG to ./lowres/06770035.JPG
# Attempting ./toadd/06670037.JPG
# Converted ./toadd/06670037.JPG to ./lowres/06670037.JPG
# Attempting ./toadd/06720006.JPG
# Converted ./toadd/06720006.JPG to ./lowres/06720006.JPG
# Attempting ./toadd/06540004.JPG
# Converted ./toadd/06540004.JPG to ./lowres/06540004.JPG
# Attempting ./toadd/06630016.JPG
# Converted ./toadd/06630016.JPG to ./lowres/06630016.JPG
# Attempting ./toadd/06710028.JPG
# Converted ./toadd/06710028.JPG to ./lowres/06710028.JPG
# Attempting ./toadd/06570002.JPG
# Converted ./toadd/06570002.JPG to ./lowres/06570002.JPG
# Attempting ./toadd/06600011.JPG
# Converted ./toadd/06600011.JPG to ./lowres/06600011.JPG
# Attempting ./toadd/06700011.JPG
# Converted ./toadd/06700011.JPG to ./lowres/06700011.JPG
# Attempting ./toadd/06750008.JPG
# Converted ./toadd/06750008.JPG to ./lowres/06750008.JPG
# Attempting ./toadd/06530036.JPG
# Converted ./toadd/06530036.JPG to ./lowres/06530036.JPG
# Attempting ./toadd/06520033.JPG
# Converted ./toadd/06520033.JPG to ./lowres/06520033.JPG
# Attempting ./toadd/06740031.JPG
# Converted ./toadd/06740031.JPG to ./lowres/06740031.JPG
# Attempting ./toadd/06740024.JPG
# Converted ./toadd/06740024.JPG to ./lowres/06740024.JPG
# Attempting ./toadd/06520032.JPG
# Converted ./toadd/06520032.JPG to ./lowres/06520032.JPG
# Attempting ./toadd/06650035.JPG
# Converted ./toadd/06650035.JPG to ./lowres/06650035.JPG
# Attempting ./toadd/06680002.JPG
# Converted ./toadd/06680002.JPG to ./lowres/06680002.JPG
# Attempting ./toadd/06530037.JPG
# Converted ./toadd/06530037.JPG to ./lowres/06530037.JPG
# Attempting ./toadd/06610015.JPG
# Converted ./toadd/06610015.JPG to ./lowres/06610015.JPG
# Attempting ./toadd/06610029.JPG
# Converted ./toadd/06610029.JPG to ./lowres/06610029.JPG
# Attempting ./toadd/06710029.JPG
# Converted ./toadd/06710029.JPG to ./lowres/06710029.JPG
# Attempting ./toadd/06710003.JPG
# Converted ./toadd/06710003.JPG to ./lowres/06710003.JPG
# Attempting ./toadd/06570029.JPG
# Converted ./toadd/06570029.JPG to ./lowres/06570029.JPG
# Attempting ./toadd/06560004.JPG
# Converted ./toadd/06560004.JPG to ./lowres/06560004.JPG
# Attempting ./toadd/06680028.JPG
# Converted ./toadd/06680028.JPG to ./lowres/06680028.JPG
# Attempting ./toadd/06530009.JPG
# Converted ./toadd/06530009.JPG to ./lowres/06530009.JPG
# Attempting ./toadd/06640027.JPG
# Converted ./toadd/06640027.JPG to ./lowres/06640027.JPG
# Attempting ./toadd/06680001.JPG
# Converted ./toadd/06680001.JPG to ./lowres/06680001.JPG
# Attempting ./toadd/06530034.JPG
# Converted ./toadd/06530034.JPG to ./lowres/06530034.JPG
# Attempting ./toadd/06700013.JPG
# Converted ./toadd/06700013.JPG to ./lowres/06700013.JPG
# Attempting ./toadd/06710002.JPG
# Converted ./toadd/06710002.JPG to ./lowres/06710002.JPG
# Attempting ./toadd/06570010.JPG
# Converted ./toadd/06570010.JPG to ./lowres/06570010.JPG
# Attempting ./toadd/06700003.JPG
# Converted ./toadd/06700003.JPG to ./lowres/06700003.JPG
# Attempting ./toadd/06680011.JPG
# Converted ./toadd/06680011.JPG to ./lowres/06680011.JPG
# Attempting ./toadd/06740023.JPG
# Converted ./toadd/06740023.JPG to ./lowres/06740023.JPG
# Attempting ./toadd/06520021.JPG
# Converted ./toadd/06520021.JPG to ./lowres/06520021.JPG
# Attempting ./toadd/06520020.JPG
# Converted ./toadd/06520020.JPG to ./lowres/06520020.JPG
# Attempting ./toadd/06520008.JPG
# Converted ./toadd/06520008.JPG to ./lowres/06520008.JPG
# Attempting ./toadd/06640036.JPG
# Converted ./toadd/06640036.JPG to ./lowres/06640036.JPG
# Attempting ./toadd/06740022.JPG
# Converted ./toadd/06740022.JPG to ./lowres/06740022.JPG
# Attempting ./toadd/06650033.JPG
# Converted ./toadd/06650033.JPG to ./lowres/06650033.JPG
# Attempting ./toadd/06750027.JPG
# Converted ./toadd/06750027.JPG to ./lowres/06750027.JPG
# Attempting ./toadd/06700002.JPG
# Converted ./toadd/06700002.JPG to ./lowres/06700002.JPG
# Attempting ./toadd/06570011.JPG
# Converted ./toadd/06570011.JPG to ./lowres/06570011.JPG
# Attempting ./toadd/06570005.JPG
# Converted ./toadd/06570005.JPG to ./lowres/06570005.JPG
# Attempting ./toadd/06680006.JPG
# Converted ./toadd/06680006.JPG to ./lowres/06680006.JPG
# Attempting ./toadd/06650025.JPG
# Converted ./toadd/06650025.JPG to ./lowres/06650025.JPG
# Attempting ./toadd/06530033.JPG
# Converted ./toadd/06530033.JPG to ./lowres/06530033.JPG
# Attempting ./toadd/06650019.JPG
# Converted ./toadd/06650019.JPG to ./lowres/06650019.JPG
# Attempting ./toadd/06690017.JPG
# Converted ./toadd/06690017.JPG to ./lowres/06690017.JPG
# Attempting ./toadd/06690003.JPG
# Converted ./toadd/06690003.JPG to ./lowres/06690003.JPG
# Attempting ./toadd/06690002.JPG
# Converted ./toadd/06690002.JPG to ./lowres/06690002.JPG
# Attempting ./toadd/06690016.JPG
# Converted ./toadd/06690016.JPG to ./lowres/06690016.JPG
# Attempting ./toadd/06680007.JPG
# Converted ./toadd/06680007.JPG to ./lowres/06680007.JPG
# Attempting ./toadd/06650030.JPG
# Converted ./toadd/06650030.JPG to ./lowres/06650030.JPG
# Attempting ./toadd/06610010.JPG
# Converted ./toadd/06610010.JPG to ./lowres/06610010.JPG
# Attempting ./toadd/06570023.JPG
# Converted ./toadd/06570023.JPG to ./lowres/06570023.JPG
# Attempting ./toadd/06710035.JPG
# Converted ./toadd/06710035.JPG to ./lowres/06710035.JPG
# Attempting ./toadd/06700018.JPG
# Converted ./toadd/06700018.JPG to ./lowres/06700018.JPG
# Attempting ./toadd/06650029.JPG
# Converted ./toadd/06650029.JPG to ./lowres/06650029.JPG
# Attempting ./toadd/06530017.JPG
# Converted ./toadd/06530017.JPG to ./lowres/06530017.JPG
# Attempting ./toadd/06690033.JPG
# Converted ./toadd/06690033.JPG to ./lowres/06690033.JPG
# Attempting ./toadd/06600025.JPG
# Converted ./toadd/06600025.JPG to ./lowres/06600025.JPG
# Attempting ./toadd/06700019.JPG
# Converted ./toadd/06700019.JPG to ./lowres/06700019.JPG
# Attempting ./toadd/06560027.JPG
# Converted ./toadd/06560027.JPG to ./lowres/06560027.JPG
# Attempting ./toadd/06570022.JPG
# Converted ./toadd/06570022.JPG to ./lowres/06570022.JPG
# Attempting ./toadd/06570036.JPG
# Converted ./toadd/06570036.JPG to ./lowres/06570036.JPG
# Attempting ./toadd/06710022.JPG
# Converted ./toadd/06710022.JPG to ./lowres/06710022.JPG
# Attempting ./toadd/06690019.JPG
# Converted ./toadd/06690019.JPG to ./lowres/06690019.JPG
# Attempting ./toadd/06680034.JPG
# Converted ./toadd/06680034.JPG to ./lowres/06680034.JPG
# Attempting ./toadd/06530015.JPG
# Converted ./toadd/06530015.JPG to ./lowres/06530015.JPG
# Attempting ./toadd/06710033.JPG
# Converted ./toadd/06710033.JPG to ./lowres/06710033.JPG
# Attempting ./toadd/06560034.JPG
# Converted ./toadd/06560034.JPG to ./lowres/06560034.JPG
# Attempting ./toadd/06530011.JPG
# Converted ./toadd/06530011.JPG to ./lowres/06530011.JPG
# Attempting ./toadd/06530005.JPG
# Converted ./toadd/06530005.JPG to ./lowres/06530005.JPG
# Attempting ./toadd/06680018.JPG
# Converted ./toadd/06680018.JPG to ./lowres/06680018.JPG
# Attempting ./toadd/06690021.JPG
# Converted ./toadd/06690021.JPG to ./lowres/06690021.JPG
# Attempting ./toadd/06740017.JPG
# Converted ./toadd/06740017.JPG to ./lowres/06740017.JPG
# Attempting ./toadd/06520029.JPG
# Converted ./toadd/06520029.JPG to ./lowres/06520029.JPG
# Attempting ./toadd/06740003.JPG
# Converted ./toadd/06740003.JPG to ./lowres/06740003.JPG
# Attempting ./toadd/06700009.JPG
# Converted ./toadd/06700009.JPG to ./lowres/06700009.JPG
# Attempting ./toadd/06750004.JPG
# Converted ./toadd/06750004.JPG to ./lowres/06750004.JPG
# Attempting ./toadd/06680033.JPG
# Converted ./toadd/06680033.JPG to ./lowres/06680033.JPG
# Attempting ./toadd/06530012.JPG
# Converted ./toadd/06530012.JPG to ./lowres/06530012.JPG
# Attempting ./toadd/06690022.JPG
# Converted ./toadd/06690022.JPG to ./lowres/06690022.JPG
# Attempting ./toadd/06530007.JPG
# Converted ./toadd/06530007.JPG to ./lowres/06530007.JPG
# Attempting ./toadd/06650005.JPG
# Converted ./toadd/06650005.JPG to ./lowres/06650005.JPG
# Attempting ./toadd/06660016.JPG
# Converted ./toadd/06660016.JPG to ./lowres/06660016.JPG
# Attempting ./toadd/06760002.JPG
# Converted ./toadd/06760002.JPG to ./lowres/06760002.JPG
# Attempting ./toadd/06550019.JPG
# Converted ./toadd/06550019.JPG to ./lowres/06550019.JPG
# Attempting ./toadd/06590017.JPG
# Converted ./toadd/06590017.JPG to ./lowres/06590017.JPG
# Attempting ./toadd/06540034.JPG
# Converted ./toadd/06540034.JPG to ./lowres/06540034.JPG
# Attempting ./toadd/06590003.JPG
# Converted ./toadd/06590003.JPG to ./lowres/06590003.JPG
# Attempting ./toadd/06620023.JPG
# Converted ./toadd/06620023.JPG to ./lowres/06620023.JPG
# Attempting ./toadd/06540009.JPG
# Converted ./toadd/06540009.JPG to ./lowres/06540009.JPG
# Attempting ./toadd/06590016.JPG
# Converted ./toadd/06590016.JPG to ./lowres/06590016.JPG
# Attempting ./toadd/06550018.JPG
# Converted ./toadd/06550018.JPG to ./lowres/06550018.JPG
# Attempting ./toadd/06630032.JPG
# Converted ./toadd/06630032.JPG to ./lowres/06630032.JPG
# Attempting ./toadd/06660017.JPG
# Converted ./toadd/06660017.JPG to ./lowres/06660017.JPG
# Attempting ./toadd/06670010.JPG
# Converted ./toadd/06670010.JPG to ./lowres/06670010.JPG
# Attempting ./toadd/06660029.JPG
# Converted ./toadd/06660029.JPG to ./lowres/06660029.JPG
# Attempting ./toadd/06760001.JPG
# Converted ./toadd/06760001.JPG to ./lowres/06760001.JPG
# Attempting ./toadd/06730018.JPG
# Converted ./toadd/06730018.JPG to ./lowres/06730018.JPG
# Attempting ./toadd/06630024.JPG
# Converted ./toadd/06630024.JPG to ./lowres/06630024.JPG
# Attempting ./toadd/06620035.JPG
# Converted ./toadd/06620035.JPG to ./lowres/06620035.JPG
# Attempting ./toadd/06730031.JPG
# Converted ./toadd/06730031.JPG to ./lowres/06730031.JPG
# Attempting ./toadd/06630025.JPG
# Converted ./toadd/06630025.JPG to ./lowres/06630025.JPG
# Attempting ./toadd/06550033.JPG
# Converted ./toadd/06550033.JPG to ./lowres/06550033.JPG
# Attempting ./toadd/06760014.JPG
# Converted ./toadd/06760014.JPG to ./lowres/06760014.JPG
# Attempting ./toadd/06660014.JPG
# Converted ./toadd/06660014.JPG to ./lowres/06660014.JPG
# Attempting ./toadd/06660010.JPG
# Converted ./toadd/06660010.JPG to ./lowres/06660010.JPG
# Attempting ./toadd/06760010.JPG
# Converted ./toadd/06760010.JPG to ./lowres/06760010.JPG
# Attempting ./toadd/06730035.JPG
# Converted ./toadd/06730035.JPG to ./lowres/06730035.JPG
# Attempting ./toadd/06630009.JPG
# Converted ./toadd/06630009.JPG to ./lowres/06630009.JPG
# Attempting ./toadd/06620024.JPG
# Converted ./toadd/06620024.JPG to ./lowres/06620024.JPG
# Attempting ./toadd/06590011.JPG
# Converted ./toadd/06590011.JPG to ./lowres/06590011.JPG
# Attempting ./toadd/06580001.JPG
# Converted ./toadd/06580001.JPG to ./lowres/06580001.JPG
# Attempting ./toadd/06660011.JPG
# Converted ./toadd/06660011.JPG to ./lowres/06660011.JPG
# Attempting ./toadd/06760005.JPG
# Converted ./toadd/06760005.JPG to ./lowres/06760005.JPG
# Attempting ./toadd/06660013.JPG
# Converted ./toadd/06660013.JPG to ./lowres/06660013.JPG
# Attempting ./toadd/06630036.JPG
# Converted ./toadd/06630036.JPG to ./lowres/06630036.JPG
# Attempting ./toadd/06730022.JPG
# Converted ./toadd/06730022.JPG to ./lowres/06730022.JPG
# Attempting ./toadd/06580017.JPG
# Converted ./toadd/06580017.JPG to ./lowres/06580017.JPG
# Attempting ./toadd/06720027.JPG
# Converted ./toadd/06720027.JPG to ./lowres/06720027.JPG
# Attempting ./toadd/06550021.JPG
# Converted ./toadd/06550021.JPG to ./lowres/06550021.JPG
# Attempting ./toadd/06760006.JPG
# Converted ./toadd/06760006.JPG to ./lowres/06760006.JPG
# Attempting ./toadd/06660012.JPG
# Converted ./toadd/06660012.JPG to ./lowres/06660012.JPG
# Attempting ./toadd/06670017.JPG
# Converted ./toadd/06670017.JPG to ./lowres/06670017.JPG
