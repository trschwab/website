# %%
import os
from PIL import Image, ExifTags

def correct_image_orientation(img):
    try:
        for orientation in ExifTags.TAGS.keys():
            if ExifTags.TAGS[orientation] == 'Orientation':
                break
        exif = img._getexif()
        if exif is not None:
            orientation = exif.get(orientation, None)
            if orientation == 3:
                img = img.rotate(180, expand=True)
            elif orientation == 6:
                img = img.rotate(270, expand=True)
            elif orientation == 8:
                img = img.rotate(90, expand=True)
    except (AttributeError, KeyError, IndexError):
        # Cases where there is no EXIF data or orientation information
        pass
    return img

def create_low_res_image(input_path, output_path, scale_factor):
    with Image.open(input_path) as img:
        # Correct orientation based on EXIF data
        img = correct_image_orientation(img)
        
        # Calculate new dimensions
        new_width = int(img.width * scale_factor)
        new_height = int(img.height * scale_factor)
        
        # Resize the image
        img = img.resize((new_width, new_height), Image.ANTIALIAS)
        
        # Save the resized image
        img.save(output_path)

def process_directory(input_dir, output_dir, scale_factor):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(('png', 'jpg', 'jpeg', 'tiff', 'bmp', 'gif')):
                input_path = os.path.join(root, file)
                print(f"Attempting {input_path}")
                relative_path = os.path.relpath(input_path, input_dir)
                output_path = os.path.join(output_dir, relative_path)

                output_dir_for_file = os.path.dirname(output_path)
                if not os.path.exists(output_dir_for_file):
                    os.makedirs(output_dir_for_file)

                create_low_res_image(input_path, output_path, scale_factor)
                print(f'Converted {input_path} to {output_path}')

input_directory = "./toadd/"
output_directory = "./midres/"
scale_factor = 0.8

process_directory(input_directory, output_directory, scale_factor)

input_directory = "./toadd/"
output_directory = "./lowres/"
scale_factor = 0.5

process_directory(input_directory, output_directory, scale_factor)
# Out:
# Attempting ./toadd/94930032.JPG
# Converted ./toadd/94930032.JPG to ./midres/94930032.JPG
# Attempting ./toadd/94930027.JPG
# Converted ./toadd/94930027.JPG to ./midres/94930027.JPG
# Attempting ./toadd/94920020.JPG
# Converted ./toadd/94920020.JPG to ./midres/94920020.JPG
# Attempting ./toadd/94930034.JPG
# Converted ./toadd/94930034.JPG to ./midres/94930034.JPG
# Attempting ./toadd/94920018.JPG
# Converted ./toadd/94920018.JPG to ./midres/94920018.JPG
# Attempting ./toadd/94890032.JPG
# Converted ./toadd/94890032.JPG to ./midres/94890032.JPG
# Attempting ./toadd/94910008.JPG
# Converted ./toadd/94910008.JPG to ./midres/94910008.JPG
# Attempting ./toadd/94900024.JPG
# Converted ./toadd/94900024.JPG to ./midres/94900024.JPG
# Attempting ./toadd/94900027.JPG
# Converted ./toadd/94900027.JPG to ./midres/94900027.JPG
# Attempting ./toadd/94900023.JPG
# Converted ./toadd/94900023.JPG to ./midres/94900023.JPG
# Attempting ./toadd/94910027.JPG
# Converted ./toadd/94910027.JPG to ./midres/94910027.JPG
# Attempting ./toadd/94910025.JPG
# Converted ./toadd/94910025.JPG to ./midres/94910025.JPG
# Attempting ./toadd/94890036.JPG
# Converted ./toadd/94890036.JPG to ./midres/94890036.JPG
# Attempting ./toadd/94890010.JPG
# Converted ./toadd/94890010.JPG to ./midres/94890010.JPG
# Attempting ./toadd/94910017.JPG
# Converted ./toadd/94910017.JPG to ./midres/94910017.JPG
# Attempting ./toadd/94890016.JPG
# Converted ./toadd/94890016.JPG to ./midres/94890016.JPG
# Attempting ./toadd/94910004.JPG
# Converted ./toadd/94910004.JPG to ./midres/94910004.JPG
# Attempting ./toadd/94900029.JPG
# Converted ./toadd/94900029.JPG to ./midres/94900029.JPG
# Attempting ./toadd/94930012.JPG
# Converted ./toadd/94930012.JPG to ./midres/94930012.JPG
# Attempting ./toadd/94930016.JPG
# Converted ./toadd/94930016.JPG to ./midres/94930016.JPG
# Attempting ./toadd/94920013.JPG
# Converted ./toadd/94920013.JPG to ./midres/94920013.JPG
# Attempting ./toadd/94930003.JPG
# Converted ./toadd/94930003.JPG to ./midres/94930003.JPG
# Attempting ./toadd/94930017.JPG
# Converted ./toadd/94930017.JPG to ./midres/94930017.JPG
# Attempting ./toadd/94930032.JPG
# Converted ./toadd/94930032.JPG to ./lowres/94930032.JPG
# Attempting ./toadd/94930027.JPG
# Converted ./toadd/94930027.JPG to ./lowres/94930027.JPG
# Attempting ./toadd/94920020.JPG
# Converted ./toadd/94920020.JPG to ./lowres/94920020.JPG
# Attempting ./toadd/94930034.JPG
# Converted ./toadd/94930034.JPG to ./lowres/94930034.JPG
# Attempting ./toadd/94920018.JPG
# Converted ./toadd/94920018.JPG to ./lowres/94920018.JPG
# Attempting ./toadd/94890032.JPG
# Converted ./toadd/94890032.JPG to ./lowres/94890032.JPG
# Attempting ./toadd/94910008.JPG
# Converted ./toadd/94910008.JPG to ./lowres/94910008.JPG
# Attempting ./toadd/94900024.JPG
# Converted ./toadd/94900024.JPG to ./lowres/94900024.JPG
# Attempting ./toadd/94900027.JPG
# Converted ./toadd/94900027.JPG to ./lowres/94900027.JPG
# Attempting ./toadd/94900023.JPG
# Converted ./toadd/94900023.JPG to ./lowres/94900023.JPG
# Attempting ./toadd/94910027.JPG
# Converted ./toadd/94910027.JPG to ./lowres/94910027.JPG
# Attempting ./toadd/94910025.JPG
# Converted ./toadd/94910025.JPG to ./lowres/94910025.JPG
# Attempting ./toadd/94890036.JPG
# Converted ./toadd/94890036.JPG to ./lowres/94890036.JPG
# Attempting ./toadd/94890010.JPG
# Converted ./toadd/94890010.JPG to ./lowres/94890010.JPG
# Attempting ./toadd/94910017.JPG
# Converted ./toadd/94910017.JPG to ./lowres/94910017.JPG
# Attempting ./toadd/94890016.JPG
# Converted ./toadd/94890016.JPG to ./lowres/94890016.JPG
# Attempting ./toadd/94910004.JPG
# Converted ./toadd/94910004.JPG to ./lowres/94910004.JPG
# Attempting ./toadd/94900029.JPG
# Converted ./toadd/94900029.JPG to ./lowres/94900029.JPG
# Attempting ./toadd/94930012.JPG
# Converted ./toadd/94930012.JPG to ./lowres/94930012.JPG
# Attempting ./toadd/94930016.JPG
# Converted ./toadd/94930016.JPG to ./lowres/94930016.JPG
# Attempting ./toadd/94920013.JPG
# Converted ./toadd/94920013.JPG to ./lowres/94920013.JPG
# Attempting ./toadd/94930003.JPG
# Converted ./toadd/94930003.JPG to ./lowres/94930003.JPG
# Attempting ./toadd/94930017.JPG
# Converted ./toadd/94930017.JPG to ./lowres/94930017.JPG
