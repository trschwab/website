# %%
import os
from PIL import Image, ExifTags

def correct_image_orientation(img):
    try:
        for orientation in ExifTags.TAGS.keys():
            if ExifTags.TAGS[orientation] == 'Orientation':
                break
        exif = img._getexif()
        if exif is not None:
            orientation = exif.get(orientation, None)
            if orientation == 3:
                img = img.rotate(180, expand=True)
            elif orientation == 6:
                img = img.rotate(270, expand=True)
            elif orientation == 8:
                img = img.rotate(90, expand=True)
    except (AttributeError, KeyError, IndexError):
        # Cases where there is no EXIF data or orientation information
        pass
    return img

def create_low_res_image(input_path, output_path, scale_factor):
    with Image.open(input_path) as img:
        # Correct orientation based on EXIF data
        img = correct_image_orientation(img)
        
        # Calculate new dimensions
        new_width = int(img.width * scale_factor)
        new_height = int(img.height * scale_factor)
        
        # Resize the image
        img = img.resize((new_width, new_height), Image.ANTIALIAS)
        
        # Save the resized image
        img.save(output_path)

def process_directory(input_dir, output_dir, scale_factor):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(('png', 'jpg', 'jpeg', 'tiff', 'bmp', 'gif')):
                input_path = os.path.join(root, file)
                print(f"Attempting {input_path}")
                relative_path = os.path.relpath(input_path, input_dir)
                output_path = os.path.join(output_dir, relative_path)

                output_dir_for_file = os.path.dirname(output_path)
                if not os.path.exists(output_dir_for_file):
                    os.makedirs(output_dir_for_file)

                create_low_res_image(input_path, output_path, scale_factor)
                print(f'Converted {input_path} to {output_path}')

input_directory = "./toadd/"
output_directory = "./midres/"
scale_factor = 0.8

process_directory(input_directory, output_directory, scale_factor)

input_directory = "./toadd/"
output_directory = "./lowres/"
scale_factor = 0.5

process_directory(input_directory, output_directory, scale_factor)
# Out:
# Attempting ./toadd/61650004.JPG
# Converted ./toadd/61650004.JPG to ./midres/61650004.JPG
# Attempting ./toadd/61600035.JPG
# Converted ./toadd/61600035.JPG to ./midres/61600035.JPG
# Attempting ./toadd/61600036.JPG
# Converted ./toadd/61600036.JPG to ./midres/61600036.JPG
# Attempting ./toadd/61690024.JPG
# Converted ./toadd/61690024.JPG to ./midres/61690024.JPG
# Attempting ./toadd/61680008.JPG
# Converted ./toadd/61680008.JPG to ./midres/61680008.JPG
# Attempting ./toadd/61650001.JPG
# Converted ./toadd/61650001.JPG to ./midres/61650001.JPG
# Attempting ./toadd/61590006.JPG
# Converted ./toadd/61590006.JPG to ./midres/61590006.JPG
# Attempting ./toadd/61670002.JPG
# Converted ./toadd/61670002.JPG to ./midres/61670002.JPG
# Attempting ./toadd/61590007.JPG
# Converted ./toadd/61590007.JPG to ./midres/61590007.JPG
# Attempting ./toadd/61590005.JPG
# Converted ./toadd/61590005.JPG to ./midres/61590005.JPG
# Attempting ./toadd/61590011.JPG
# Converted ./toadd/61590011.JPG to ./midres/61590011.JPG
# Attempting ./toadd/61580014.JPG
# Converted ./toadd/61580014.JPG to ./midres/61580014.JPG
# Attempting ./toadd/61620025.JPG
# Converted ./toadd/61620025.JPG to ./midres/61620025.JPG
# Attempting ./toadd/61580005.JPG
# Converted ./toadd/61580005.JPG to ./midres/61580005.JPG
# Attempting ./toadd/61670005.JPG
# Converted ./toadd/61670005.JPG to ./midres/61670005.JPG
# Attempting ./toadd/61620036.JPG
# Converted ./toadd/61620036.JPG to ./midres/61620036.JPG
# Attempting ./toadd/61630032.JPG
# Converted ./toadd/61630032.JPG to ./midres/61630032.JPG
# Attempting ./toadd/61630017.JPG
# Converted ./toadd/61630017.JPG to ./midres/61630017.JPG
# Attempting ./toadd/61630002.JPG
# Converted ./toadd/61630002.JPG to ./midres/61630002.JPG
# Attempting ./toadd/61590018.JPG
# Converted ./toadd/61590018.JPG to ./midres/61590018.JPG
# Attempting ./toadd/61620011.JPG
# Converted ./toadd/61620011.JPG to ./midres/61620011.JPG
# Attempting ./toadd/61660025.JPG
# Converted ./toadd/61660025.JPG to ./midres/61660025.JPG
# Attempting ./toadd/61660019.JPG
# Converted ./toadd/61660019.JPG to ./midres/61660019.JPG
# Attempting ./toadd/61590019.JPG
# Converted ./toadd/61590019.JPG to ./midres/61590019.JPG
# Attempting ./toadd/61670024.JPG
# Converted ./toadd/61670024.JPG to ./midres/61670024.JPG
# Attempting ./toadd/61670018.JPG
# Converted ./toadd/61670018.JPG to ./midres/61670018.JPG
# Attempting ./toadd/61590022.JPG
# Converted ./toadd/61590022.JPG to ./midres/61590022.JPG
# Attempting ./toadd/61610005.JPG
# Converted ./toadd/61610005.JPG to ./midres/61610005.JPG
# Attempting ./toadd/61610010.JPG
# Converted ./toadd/61610010.JPG to ./midres/61610010.JPG
# Attempting ./toadd/61600029.JPG
# Converted ./toadd/61600029.JPG to ./midres/61600029.JPG
# Attempting ./toadd/61680007.JPG
# Converted ./toadd/61680007.JPG to ./midres/61680007.JPG
# Attempting ./toadd/61610013.JPG
# Converted ./toadd/61610013.JPG to ./midres/61610013.JPG
# Attempting ./toadd/61600002.JPG
# Converted ./toadd/61600002.JPG to ./midres/61600002.JPG
# Attempting ./toadd/61680010.JPG
# Converted ./toadd/61680010.JPG to ./midres/61680010.JPG
# Attempting ./toadd/61680014.JPG
# Converted ./toadd/61680014.JPG to ./midres/61680014.JPG
# Attempting ./toadd/61680001.JPG
# Converted ./toadd/61680001.JPG to ./midres/61680001.JPG
# Attempting ./toadd/61680003.JPG
# Converted ./toadd/61680003.JPG to ./midres/61680003.JPG
# Attempting ./toadd/61700005.JPG
# Converted ./toadd/61700005.JPG to ./midres/61700005.JPG
# Attempting ./toadd/61650004.JPG
# Converted ./toadd/61650004.JPG to ./lowres/61650004.JPG
# Attempting ./toadd/61600035.JPG
# Converted ./toadd/61600035.JPG to ./lowres/61600035.JPG
# Attempting ./toadd/61600036.JPG
# Converted ./toadd/61600036.JPG to ./lowres/61600036.JPG
# Attempting ./toadd/61690024.JPG
# Converted ./toadd/61690024.JPG to ./lowres/61690024.JPG
# Attempting ./toadd/61680008.JPG
# Converted ./toadd/61680008.JPG to ./lowres/61680008.JPG
# Attempting ./toadd/61650001.JPG
# Converted ./toadd/61650001.JPG to ./lowres/61650001.JPG
# Attempting ./toadd/61590006.JPG
# Converted ./toadd/61590006.JPG to ./lowres/61590006.JPG
# Attempting ./toadd/61670002.JPG
# Converted ./toadd/61670002.JPG to ./lowres/61670002.JPG
# Attempting ./toadd/61590007.JPG
# Converted ./toadd/61590007.JPG to ./lowres/61590007.JPG
# Attempting ./toadd/61590005.JPG
# Converted ./toadd/61590005.JPG to ./lowres/61590005.JPG
# Attempting ./toadd/61590011.JPG
# Converted ./toadd/61590011.JPG to ./lowres/61590011.JPG
# Attempting ./toadd/61580014.JPG
# Converted ./toadd/61580014.JPG to ./lowres/61580014.JPG
# Attempting ./toadd/61620025.JPG
# Converted ./toadd/61620025.JPG to ./lowres/61620025.JPG
# Attempting ./toadd/61580005.JPG
# Converted ./toadd/61580005.JPG to ./lowres/61580005.JPG
# Attempting ./toadd/61670005.JPG
# Converted ./toadd/61670005.JPG to ./lowres/61670005.JPG
# Attempting ./toadd/61620036.JPG
# Converted ./toadd/61620036.JPG to ./lowres/61620036.JPG
# Attempting ./toadd/61630032.JPG
# Converted ./toadd/61630032.JPG to ./lowres/61630032.JPG
# Attempting ./toadd/61630017.JPG
# Converted ./toadd/61630017.JPG to ./lowres/61630017.JPG
# Attempting ./toadd/61630002.JPG
# Converted ./toadd/61630002.JPG to ./lowres/61630002.JPG
# Attempting ./toadd/61590018.JPG
# Converted ./toadd/61590018.JPG to ./lowres/61590018.JPG
# Attempting ./toadd/61620011.JPG
# Converted ./toadd/61620011.JPG to ./lowres/61620011.JPG
# Attempting ./toadd/61660025.JPG
# Converted ./toadd/61660025.JPG to ./lowres/61660025.JPG
# Attempting ./toadd/61660019.JPG
# Converted ./toadd/61660019.JPG to ./lowres/61660019.JPG
# Attempting ./toadd/61590019.JPG
# Converted ./toadd/61590019.JPG to ./lowres/61590019.JPG
# Attempting ./toadd/61670024.JPG
# Converted ./toadd/61670024.JPG to ./lowres/61670024.JPG
# Attempting ./toadd/61670018.JPG
# Converted ./toadd/61670018.JPG to ./lowres/61670018.JPG
# Attempting ./toadd/61590022.JPG
# Converted ./toadd/61590022.JPG to ./lowres/61590022.JPG
# Attempting ./toadd/61610005.JPG
# Converted ./toadd/61610005.JPG to ./lowres/61610005.JPG
# Attempting ./toadd/61610010.JPG
# Converted ./toadd/61610010.JPG to ./lowres/61610010.JPG
# Attempting ./toadd/61600029.JPG
# Converted ./toadd/61600029.JPG to ./lowres/61600029.JPG
# Attempting ./toadd/61680007.JPG
# Converted ./toadd/61680007.JPG to ./lowres/61680007.JPG
# Attempting ./toadd/61610013.JPG
# Converted ./toadd/61610013.JPG to ./lowres/61610013.JPG
# Attempting ./toadd/61600002.JPG
# Converted ./toadd/61600002.JPG to ./lowres/61600002.JPG
# Attempting ./toadd/61680010.JPG
# Converted ./toadd/61680010.JPG to ./lowres/61680010.JPG
# Attempting ./toadd/61680014.JPG
# Converted ./toadd/61680014.JPG to ./lowres/61680014.JPG
# Attempting ./toadd/61680001.JPG
# Converted ./toadd/61680001.JPG to ./lowres/61680001.JPG
# Attempting ./toadd/61680003.JPG
# Converted ./toadd/61680003.JPG to ./lowres/61680003.JPG
# Attempting ./toadd/61700005.JPG
# Converted ./toadd/61700005.JPG to ./lowres/61700005.JPG
