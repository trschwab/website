# %%
import os
from PIL import Image, ExifTags

# Map EXIF orientation values to rotation angles
orientation_to_rotation = {
    3: 180,
    6: 270,
    8: 90
}

# List all files in the current directory
files = [f for f in os.listdir('.') if os.path.isfile(f)]

for f in files:
    if "test" in f:
        continue
    else:
        try:
            # Open the image file
            with Image.open(f) as img:
                # Check if the image has EXIF data
                exif = img._getexif()
                if exif:
                    # Get orientation tag (if it exists)
                    for tag, value in ExifTags.TAGS.items():
                        if value == 'Orientation':
                            orientation_tag = tag
                            break

                    # Apply rotation if necessary
                    if orientation_tag in exif:
                        orientation = exif.get(orientation_tag)
                        if orientation in orientation_to_rotation:
                            img = img.rotate(orientation_to_rotation[orientation], expand=True)

                # Get the dimensions after potential rotation
                width, height = img.size
                print(f'{{ src: "{f}", width: {width}, height: {height} }}, //')
                # { src: "61650004.JPG", width: 3583, height: 2376 }, // NY Building w Covering
        except IOError:
            # Skip files that are not images
            pass
# Out:
# { src: "/54160001.JPG", width: 3583, height: 2376 }, //
# { src: "/54210012.JPG", width: 3583, height: 2376 }, //
# { src: "/54210006.JPG", width: 3583, height: 2376 }, //
# { src: "/54160017.JPG", width: 2376, height: 3583 }, //
# { src: "/54200010.JPG", width: 3583, height: 2376 }, //
# { src: "/54160007.JPG", width: 2376, height: 3583 }, //
# { src: "/54210002.JPG", width: 2376, height: 3583 }, //
# { src: "/54160011.JPG", width: 3583, height: 2376 }, //
# { src: "/54160010.JPG", width: 2376, height: 3583 }, //
# { src: "/54160004.JPG", width: 3583, height: 2376 }, //
# { src: "/54150003.JPG", width: 3583, height: 2376 }, //
# { src: "/54180034.JPG", width: 3583, height: 2376 }, //
# { src: "/54190025.JPG", width: 2376, height: 3583 }, //
# { src: "/54190024.JPG", width: 3583, height: 2376 }, //
# { src: "/54190032.JPG", width: 3583, height: 2376 }, //
# { src: "/54220012.JPG", width: 3583, height: 2376 }, //
# { src: "/54220014.JPG", width: 3583, height: 2376 }, //
# { src: "/54180030.JPG", width: 3583, height: 2376 }, //
# { src: "/54230020.JPG", width: 3583, height: 2376 }, //
# { src: "/54180015.JPG", width: 3583, height: 2376 }, //
# { src: "/54220019.JPG", width: 3583, height: 2376 }, //
# { src: "/54180002.JPG", width: 2376, height: 3583 }, //
# { src: "/54140018.JPG", width: 3583, height: 2376 }, //
# { src: "/54190007.JPG", width: 2376, height: 3583 }, //
# { src: "/54180003.JPG", width: 3583, height: 2376 }, //
# { src: "/54230036.JPG", width: 3583, height: 2376 }, //
# { src: "/54230032.JPG", width: 2376, height: 3583 }, //
# { src: "/54220023.JPG", width: 2376, height: 3583 }, //
# { src: "/54190017.JPG", width: 3583, height: 2376 }, //
# { src: "/54220021.JPG", width: 3583, height: 2376 }, //
# { src: "/54160023.JPG", width: 2376, height: 3583 }, //
# { src: "/54170022.JPG", width: 2376, height: 3583 }, //
# { src: "/54160026.JPG", width: 3583, height: 2376 }, //
# { src: "/54160031.JPG", width: 3583, height: 2376 }, //
